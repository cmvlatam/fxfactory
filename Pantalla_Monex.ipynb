# %%
import bccr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline
from bccr import PW
from bccr import SW
import lxml
from bs4 import BeautifulSoup

# %%
monex_pxlast = float(1*SW(3435).iloc[-1])
monex_pp = float(1*SW(3439).iloc[-1])

monexbbid = float(1*SW(3442).iloc[-1])
monexbbidm = float(1*SW(3452).iloc[-1])

monexbask = float(1*SW(3443).iloc[-1])
monexbaskm = float(1*SW(3453).iloc[-1])

monexmonto = float(1*SW(3443).iloc[-1])

print(monex_pxlast)
print(monex_pp)
print(monexbbid)
print(monexbbidm)
print(monexbask)
print(monexbaskm)
# Out:
# 620.2
# 620.35
# 620.2
# 500000.0
# 620.25
# 425000.0

# %%
monex_pxlast = float(1*SW(3435).iloc[-1])
print(monex_pxlast)
# Out:
# 620.38
