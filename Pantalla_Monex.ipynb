# %%
import bccr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline
from bccr import PW
from bccr import SW
import lxml
from bs4 import BeautifulSoup

# %%
monex_pxlast = SW(3435).iloc[-1]
monex_pp = SW(3439).iloc[-1]

monexbbid = SW(3442).iloc[-1]
monexbbidm = SW(3452).iloc[-1]

monexbask = SW(3443).iloc[-1]
monexbaskm = SW(3453).iloc[-1]

monexmonto = SW(3443).iloc[-1]

print(monex_pxlast)
print(monex_pp)
print(monexbbid)
print(monexbbidm)
print(monexbask)
print(monexbaskm)
# Out:
# Ultimo    620.49
# Name: 2021-07-12, dtype: float64
# Promedio Monex durante la sesión    620.48
# Name: 2021-07-12, dtype: float64
# Mejor oferta compra    620.25
# Name: 2021-07-12, dtype: float64
# Mejor oferta compra    250000.0
# Name: 2021-07-12, dtype: float64
# Mejor oferta venta    620.45
# Name: 2021-07-12, dtype: float64
# Mejor oferta venta    1000.0
# Name: 2021-07-12, dtype: float64

# %%
monex_pxlast = float(1*SW(3435).iloc[-1])
print(monex_pxlast)
# Out:
# 620.38
