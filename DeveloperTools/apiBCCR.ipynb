# %%
#Libraries

import requests
import json
import xml
from xml.etree import ElementTree
import urllib
from bs4 import BeautifulSoup
from bccr import SW

# %%
# Create parameterized url Usin beautiful soup

indicador = "317"
fechainicio = "08/04/2021"
fechafinal = "08/04/2021"
nombre = "esteban"
subniveles = "S"
email = "ecervantes@cmvlatam.com"
token = "RST0LAENO8"


request_url = "http://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx/ObtenerIndicadoresEconomicos?Indicador="+indicador+"&FechaInicio="+fechainicio+"&FechaFinal="+fechafinal+"&Nombre="+nombre+"&SubNiveles="+subniveles+"&CorreoElectronico="+email+"&Token="+token+" HTTP/1.1"

# %%
# Submit request and format output

response_data = requests.get(request_url).json()
print(json.dumps(response_data, indent=4))

# %%
https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx
# Out:
#   File "<ipython-input-145-9aae8e0ba7da>", line 1
#     https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx
#            ^
# SyntaxError: invalid syntax

# %%
https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx
GET /Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx HTTP/1.1
# Out:
#   File "<ipython-input-146-eb1ed9f0557b>", line 1
#     https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx
#            ^
# SyntaxError: invalid syntax

# %%
response_data['text']

# %%
import requests
url="https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx"
#headers = {'content-type': 'application/soap+xml'}
headers = {'content-type': 'text/xml'}
body = """<?xml version="1.0" encoding="utf-8"?>
            <soap:Envelope xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/">
              <soap:Body>
                <ObtenerIndicadoresEconomicos xmlns="http://ws.sdde.bccr.fi.cr">
                  <Indicador>3323</Indicador>
                  <FechaInicio>08/04/2021</FechaInicio>
                  <FechaFinal>09/04/2021</FechaFinal>
                  <Nombre>esteban</Nombre>
                  <SubNiveles>Y</SubNiveles>
                  <CorreoElectronico>ecervantes@cmvlatam.com</CorreoElectronico>
                  <Token>RST0LAENO8</Token>
                </ObtenerIndicadoresEconomicos>
              </soap:Body>
            </soap:Envelope>"""
response = requests.post(url,data=body,headers=headers)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><ObtenerIndicadoresEconomicosResponse xmlns="http://ws.sdde.bccr.fi.cr"><ObtenerIndicadoresEconomicosResult><xs:schema id="Datos_de_INGC011_CAT_INDICADORECONOMIC" xmlns="" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata"><xs:element name="Datos_de_INGC011_CAT_INDICADORECONOMIC" msdata:IsDataSet="true" msdata:UseCurrentLocale="true"><xs:complexType><xs:choice minOccurs="0" maxOccurs="unbounded"><xs:element name="INGC011_CAT_INDICADORECONOMIC"><xs:complexType><xs:sequence><xs:element name="COD_INDICADORINTERNO" type="xs:string" minOccurs="0" /><xs:element name="DES_FECHA" type="xs:dateTime" minOccurs="0" /><xs:element name="NUM_VALOR" type="xs:decimal" minOccurs="0" /></xs:sequence></xs:complexType></xs:element></xs:choice>
# ...

# %%
import requests
url="https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx"
#headers = {'content-type': 'application/soap+xml'}
headers = {'content-type': 'text/xml'}
body = """<?xml version="1.0" encoding="utf-8"?>
            <soap:Envelope xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/">
              <soap:Body>
                <ObtenerIndicadoresEconomicos xmlns="http://ws.sdde.bccr.fi.cr">
                  <Indicador>3323</Indicador>
                  <FechaInicio>08/04/2021</FechaInicio>
                  <FechaFinal>09/04/2021</FechaFinal>
                  <Nombre>esteban</Nombre>
                  <SubNiveles>Y</SubNiveles>
                  <CorreoElectronico>ecervantes@cmvlatam.com</CorreoElectronico>
                  <Token>RST0LAENO8</Token>
                </ObtenerIndicadoresEconomicos>
              </soap:Body>
            </soap:Envelope>"""
response = requests.post(url,data=body,headers=headers)


response.text
# Out:
# '<?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><ObtenerIndicadoresEconomicosResponse xmlns="http://ws.sdde.bccr.fi.cr"><ObtenerIndicadoresEconomicosResult><xs:schema id="Datos_de_INGC011_CAT_INDICADORECONOMIC" xmlns="" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata"><xs:element name="Datos_de_INGC011_CAT_INDICADORECONOMIC" msdata:IsDataSet="true" msdata:UseCurrentLocale="true"><xs:complexType><xs:choice minOccurs="0" maxOccurs="unbounded"><xs:element name="INGC011_CAT_INDICADORECONOMIC"><xs:complexType><xs:sequence><xs:element name="COD_INDICADORINTERNO" type="xs:string" minOccurs="0" /><xs:element name="DES_FECHA" type="xs:dateTime" minOccurs="0" /><xs:element name="NUM_VALOR" type="xs:decimal" minOccurs="0" /></xs:sequence></xs:complexType></xs:element></xs:choice><
# ...

# %%
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><ObtenerIndicadoresEconomicosResponse xmlns="http://ws.sdde.bccr.fi.cr"><ObtenerIndicadoresEconomicosResult><xs:schema id="Datos_de_INGC011_CAT_INDICADORECONOMIC" xmlns="" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata"><xs:element name="Datos_de_INGC011_CAT_INDICADORECONOMIC" msdata:IsDataSet="true" msdata:UseCurrentLocale="true"><xs:complexType><xs:choice minOccurs="0" maxOccurs="unbounded"><xs:element name="INGC011_CAT_INDICADORECONOMIC"><xs:complexType><xs:sequence><xs:element name="COD_INDICADORINTERNO" type="xs:string" minOccurs="0" /><xs:element name="DES_FECHA" type="xs:dateTime" minOccurs="0" /><xs:element name="NUM_VALOR" type="xs:decimal" minOccurs="0" /></xs:sequence></xs:complexType></xs:element></xs:choice>
# ...

# %%
for monex_cierre in root.iter():
    print (monex_cierre.tag,monex_cierre.attrib)
# Out:
# {http://schemas.xmlsoap.org/soap/envelope/}Envelope {}
# {http://schemas.xmlsoap.org/soap/envelope/}Body {}
# {http://ws.sdde.bccr.fi.cr}ObtenerIndicadoresEconomicosResponse {}
# {http://ws.sdde.bccr.fi.cr}ObtenerIndicadoresEconomicosResult {}
# {http://www.w3.org/2001/XMLSchema}schema {'id': 'Datos_de_INGC011_CAT_INDICADORECONOMIC'}
# {http://www.w3.org/2001/XMLSchema}element {'name': 'Datos_de_INGC011_CAT_INDICADORECONOMIC', '{urn:schemas-microsoft-com:xml-msdata}IsDataSet': 'true', '{urn:schemas-microsoft-com:xml-msdata}UseCurrentLocale': 'true'}
# {http://www.w3.org/2001/XMLSchema}complexType {}
# {http://www.w3.org/2001/XMLSchema}choice {'minOccurs': '0', 'maxOccurs': 'unbounded'}
# {http://www.w3.org/2001/XMLSchema}element {'name': 'INGC011_CAT_INDICADORECONOMIC'}
# {http://www.w3.org/2001/XMLSchema}complexType {}
# {http://www.w3.org/2001/XMLSchema}sequence {}
# {http://www.w3.org/2001/XMLSchema}element {'name': 'COD_INDICADORINTERNO', 'type': 'xs:string', 'minOccurs': '0'}
# ...

# %%
import datetime
import pandas as pd
import urllib.request
from xml.dom.minidom import parse, parseString
import pandas_read_xml as pdx
fecha = datetime.date.today().strftime("%d/%m/%Y")
base_url = 'https://gee.bccr.fi.cr/Indicadores/Suscripciones/WS/wsindicadoreseconomicos.asmx/ObtenerIndicadoresEconomicosXML?Indicador={tcIndicador}&FechaInicio={tcFechaInicio}&FechaFinal={tcFechaFinal}&Nombre={tcNombre}&SubNiveles={tnSubNiveles}&CorreoElectronico={tcCorreoElectronico}&token={token}'
data = {
    'tcIndicador':'3323', 
    'tcFechaInicio': '08/04/2021',
    'tcFechaFinal':'08/04/2021', 
    'tcNombre':"esteban", 
    'tnSubNiveles':'S',
    'tcCorreoElectronico':'ecervantes@cmvlatam.com',
    'token':'RST0LAENO8'
}
result = urllib.request.urlopen(base_url.format(**data)).read()



print(result.decode('UTF8'))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <string xmlns="http://ws.sdde.bccr.fi.cr">&lt;Datos_de_INGC011_CAT_INDICADORECONOMIC&gt;
#   &lt;INGC011_CAT_INDICADORECONOMIC&gt;
#     &lt;COD_INDICADORINTERNO&gt;3323&lt;/COD_INDICADORINTERNO&gt;
#     &lt;DES_FECHA&gt;2021-04-08T00:00:00-06:00&lt;/DES_FECHA&gt;
#     &lt;NUM_VALOR&gt;613.51000000&lt;/NUM_VALOR&gt;
#   &lt;/INGC011_CAT_INDICADORECONOMIC&gt;
# &lt;/Datos_de_INGC011_CAT_INDICADORECONOMIC&gt;</string>

# %%
root = ET.fromstring(response.text)
