-- %% [markdown]
-- ## FX Posicion
--
-- Import fxblotter.t as a DF to make calculations
--
-- netpos = \[monto total de ventas (USD moneda base)\]  -  \[monto total de compra (USD moneda base)\]
--
-- ## Stats
--
-- total offer y pp de offer
--
-- total bid y pp de bid
--
-- ## PnL
--
-- PnL =  min \[total offer ,total bid \] \* \[ pp de offer  -  pp de bid\]  + if \[netpos \>0 , (bidtotal - offertotal) \* (monex.pp - bidpp), (offertotal - bidtotal) \* (offerpp - monexpp) \]
--
-- ## DMB
--
-- compras, ventas, cantidad por 'estado', monex compra venta
--
--
--
-- definir compras y ventas de monex como variables float insert

-- %%
SELECT SUM(montocom) AS "bidtotal"
from [fxblotter.t]
where (ccycom) = 'USD'

SELECT SUM(montoven) AS "asktotal"
from [fxblotter.t]
where [ccyven] = 'USD'
-- Out:
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.148
-- <table><tr><th>bidtotal</th></tr><tr><td>2000</td></tr></table>
-- <table><tr><th>asktotal</th></tr><tr><td>3000</td></tr></table>

-- %%
SELECT (SUM(montocom) - SUM(montoven)) AS 'total'
from [fxblotter.t]
where (ccycom) = 'USD' AND (ccyven) = 'USD'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.108
-- <table><tr><th>total</th></tr><tr><td>NULL</td></tr></table>
