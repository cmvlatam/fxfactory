-- %%
select top (5) * 
from [fxblotter.t]
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.092
-- <table><tr><th>timestamp</th><th>side</th><th>ncliente</th><th>descliente</th><th>ccycom</th><th>montocom</th><th>px_sp</th><th>ccyven</th><th>montoven</th><th>estado</th><th>ejecutivo</th><th>tradeid</th><th>action</th><th>tradedate</th><th>valuedate</th><th>monex.pxlast</th><th>monex.pp</th><th>dealer</th><th>px_cover</th><th>productotipo</th><th>segmento</th><th>solicitud</th></tr><tr><td>1900-01-01 00:00:00.000</td><td>NULL</td><td>1</td><td>Andres</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td></tr></table>

-- %%
-- Get a list of tables and views in the current database

SELECT table_name [ccy]
FROM INFORMATION_SCHEMA.TABLES

GO;
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.142
-- <table><tr><th>ccy</th></tr><tr><td>testing_data</td></tr><tr><td>clientes</td></tr><tr><td>fxblotter.t</td></tr><tr><td>fxpnl</td></tr><tr><td>database_firewall_rules</td></tr><tr><td>fxblotter.h</td></tr><tr><td>ccy</td></tr><tr><td>dmb</td></tr></table>

-- %% [markdown]
-- ## Add Drop Column a new Column

-- %%
-- Drop '[ColumnName]' from table '[TableName]' in schema '[dbo]'
ALTER TABLE [dbo].[fxblotter.t]
    DROP COLUMN [valuedate]
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.121

-- %%
-- Add a new column '[NewColumnName]' to table '[TableName]' in schema '[dbo]'
ALTER TABLE [dbo].[fxblotter.t]
ADD [valuedate] /*new_column_name*/ date /*new_column_datatype*/  /*new_column_nullability*/
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.126

-- %% [markdown]
-- Cambia el nombre de la columna

-- %%
select *
from [fxblotter.t]
full outer join [testing_data] on [fxblotter.t].TIMESTAMP = [testing_data].TIMESTAMP;
-- Out:
-- (220 rows affected)
-- Total execution time: 00:00:00.145
-- ...
